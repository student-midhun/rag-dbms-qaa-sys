# %% [markdown]
# # 04_Challenges

# %% [markdown]
# ## Challenge 1: SQL Tables Extraction
# Used pdfplumber to improve structure.

# %% [markdown]
# ## Challenge 2: Domain Terminology
# Added glossary chunks to improve retrieval.
