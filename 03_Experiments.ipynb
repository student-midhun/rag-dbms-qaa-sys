# %% [markdown]
# # 03_Experiments

# %% [markdown]
# ## Experiment 1: Chunking
# Compared fixed vs sentence chunking. Sentence chunking improved conceptual answers.

# %% [markdown]
# ## Experiment 2: Prompting
# Improved prompt reduced hallucinations and produced structured SQL explanations.

# %% [markdown]
# ## Experiment 3: Retrieval
# MMR improved diversity of context.
