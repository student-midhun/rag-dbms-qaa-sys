# %% [markdown]
# # 03_Experiments

# %% [markdown]
# Chunking comparison: fixed vs sentence.

# %% [markdown]
# Prompt comparison: basic vs tutor prompt.

# %% [markdown]
# Retrieval comparison: similarity vs MMR.
