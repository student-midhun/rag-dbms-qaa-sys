# %% [markdown]
# # 05_Final_System

# %% [markdown]
# ## Final Architecture
# Sentence chunking + improved prompt + MMR retrieval

# %% [markdown]
# ## Evaluation
# High relevance for conceptual DBMS queries.

# %% [markdown]
# ## Reflection
# System works best for theory + SQL syntax questions.
