# %% [markdown]
# # 02_Baseline_RAG

# %% [markdown]
# ## Baseline Pipeline
# 1. Load PDFs
# 2. Chunk text (fixed size)
# 3. Generate embeddings
# 4. Store in Chroma
# 5. Retrieval QA

# %% [markdown]
# ## Example Code
# ```python
# # add ingestion + rag pipeline here
# ```

# %% [markdown]
# ## Test Questions
# 1. What is DBMS?
# 2. Explain relational model
# 3. What is referential integrity?
# 4. Difference between DDL and DML
# 5. What are aggregate functions?
