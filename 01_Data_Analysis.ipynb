# %% [markdown]
# # 01_Data_Analysis

# %% [markdown]
# ## Dataset Overview
# Using provided DBMS syllabus PDFs including SQL DDL, DML, Modules 1,3,4, and aggregate functions.

# %% [markdown]
# ### Document Types
# - Lecture notes
# - SQL examples
# - Conceptual DBMS modules

# %% [markdown]
# ### Observed Challenges
# - Tables and diagrams extraction
# - Mixed formatting
# - SQL syntax blocks

# %% [markdown]
# ### Topics Covered
# - DBMS fundamentals
# - Relational model
# - SQL commands
# - Constraints
# - Aggregate functions
