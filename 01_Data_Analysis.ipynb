# %% [markdown]
# # 01_Data_Analysis

# %% [markdown]
# Dataset includes DBMS modules, SQL DDL/DML, constraints, relational model, and aggregate functions.

# %% [markdown]
# Challenges: tables, SQL syntax blocks, diagrams.
